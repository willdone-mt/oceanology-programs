# %% [markdown]
# # **SEA SURFACE TEMPERATURE AND CURRENT VISUALIZER**
# v0.0.2 || Intermediate
#
# ## Info:
# - if the raw data is not opening, run ``pip install netCDF4``
# - InDev

# %% [markdown]
# # Importing Libraries

# %%
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import matplotlib.pyplot as plt
import cartopy.mpl.ticker as cticker

# %% [markdown]
# # Opening Data

# %%
# membuka dataset
ds1 = xr.open_dataset('./raw-data/moluccas_sea_current.nc', engine='netcdf4')

ds2 = xr.open_dataset('./raw-data/moluccas_sea_temperature.nc', engine='netcdf4')

# ds3 = xr.open_dataset('Current 2024 February.nc')

# ds4 = xr.open_dataset('Temp 2024 February.nc')

# %% [markdown]
# # Inserting Variables

# %%
# Downsampling
step = 2 # Ambil setiap 10 titik

# %%
# Variabel lintang (lat) dan bujur (lon)
lon_quiver = ds1.longitude
lat_quiver = ds1.latitude

uo_values = ds1.uo.sel(
    time=ds1.time[0], 
    depth=ds1.depth[0]
    )
vo_values = ds1.vo.sel(
    time=ds1.time[0], 
    depth=ds1.depth[0]
    )

uo = uo_values[::step, ::step]
vo = vo_values [::step, ::step]


# Ambil koordinat
lon =  np.meshgrid(lon_quiver[::step])
lat =  np.meshgrid(lat_quiver[::step])

lon = np.array(lon)
lat = np.array(lat)

# ===============================
# Hitung magnitudo kecepatan arus
speed = np.sqrt(uo**2 + vo**2)

# %% [markdown]
# # Map Plotting

# %% [markdown]
# ## Current Only

# %%
# Buat plot peta
fig, ax = plt.subplots(
    figsize=(20, 12), 
    subplot_kw={'projection': ccrs.PlateCarree()}
    )
ax.set_extent([lon.min(), lon.max(), lat.min(), lat.max()], 
              crs=ccrs.PlateCarree()
              )

# Tambahkan garis pantai dan daratan
ax.add_feature(cfeature.LAND, 
               color="lightgray"
               )
ax.add_feature(cfeature.COASTLINE, 
               linewidth=0.8
               )

# Tambahkan vektor arus laut
q = ax.quiver(lon, lat, uo, vo, speed, 
              scale=5, 
              cmap="coolwarm"
              )

# Tambahkan colorbar untuk kecepatan arus
cbar = fig.colorbar(q, ax=ax, 
                    orientation="horizontal", 
                    fraction=0.05, 
                    pad=0.05
                    )
cbar.set_label("Kecepatan Arus (m/s)")

    # Tambahkan grid koordinat
gl = ax.gridlines(
    draw_labels=True, 
    linestyle="--", 
    linewidth=0.5
    )

    # Hilangkan label di kanan dan atas
gl.right_labels = False
gl.top_labels = False

# Tambahkan judul
plt.title("Sebaran Arus Laut Maluku - Januari 2024")
plt.show()

# %% [markdown]
# ## Temperature with Current Overlay

# %%
# Menentukan indeks waktu untuk Januari 2020
time_index = 0  # Pastikan ini didefinisikan sebelum digunakan

# Memilih data suhu permukaan laut (depth=0) untuk Januari 2020
t_jan = ds2["thetao"].isel(
    time=time_index, 
    depth=0
    )

t_jan = t_jan.interpolate_na(
    dim="latitude", 
    method="linear"
    )
t_jan = t_jan.interpolate_na(
    dim="longitude", 
    method="linear"
    )

# Perbaiki Grid 2D
lon2D, lat2D = np.meshgrid(lon_quiver, lat_quiver)

# Plot peta arus dengan Cartopy
fig, ax = plt.subplots(
    figsize=(20, 12), 
    subplot_kw={'projection': ccrs.PlateCarree()}
    )
ax.set_extent([lon.min(), lon.max(), lat.min(), lat.max()], 
              crs=ccrs.PlateCarree()
              )

# Tentukan batas bawah dan atas suhu
vmin = float(t_jan.min())
vmax = float(t_jan.max())

# Tambahkan latar belakang kecepatan arus
ax.add_feature(cfeature.NaturalEarthFeature("physical", "land", "10m"), 
               facecolor="gray"
               )
# for pixelated visual, use this code below
# cmap = ax.pcolormesh(lon2D, lat2D, t_jan, cmap="coolwarm", transform=ccrs.PlateCarree(), alpha=0.7, shading='nearest')
# for more antialiased visual, use this code below
cmap = ax.contourf(lon2D, lat2D, t_jan, 
                   cmap="coolwarm", 
                   transform=ccrs.PlateCarree(), 
                   alpha=0.7, 
                   extend='neither' , 
                   antialiased='True', 
                   levels = np.arange(vmin, vmax + 0.05, 0.05)
                   )

# Tambahkan garis pantai dan daratan
ax.add_feature(cfeature.LAND, 
               color="lightgray"
               )
ax.add_feature(cfeature.COASTLINE, 
               linewidth=0.8
               )

# Tambahkan vektor arus laut
q = ax.quiver(lon, lat, uo, vo, speed, 
              scale=6, 
              cmap="inferno", 
              alpha=0.8
              )

# Tambahkan colorbar untuk kecepatan arus
cbar = plt.colorbar(cmap, ax=ax, 
                    orientation="horizontal", 
                    fraction=0.05, 
                    pad=0.10
                    )
cbar.set_label("Temperature (deg C)")

cbar = fig.colorbar(q, ax=ax, 
                    orientation="horizontal", 
                    fraction=0.05, 
                    pad=0.05
                    )
cbar.set_label("Kecepatan Arus (m/s)")


# Tambahkan grid koordinat
gl = ax.gridlines(
    draw_labels=True, 
    linestyle="--", 
    linewidth=0.5,
    color='black',
    alpha=0.5
    )

# Hilangkan label di kanan dan atas
gl.right_labels = False  
gl.top_labels = False 

# Judul
ax.set_title("Sebaran Temperatur dan Arus Laut Arafura - Januari 2024", fontsize=12)

plt.show()
