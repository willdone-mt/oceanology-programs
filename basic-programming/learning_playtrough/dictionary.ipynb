# %% [markdown]
# # DICTIONARY
#
# [the python language reference!](https://docs.python.org/3/reference/index.html)

# %% [markdown]
# # Vocabularies

# %% [markdown]
# string
#
# carriage runner

# %% [markdown]
# # Sentences/ Idioms

# %%
mystring = "hello"
    # mystring = name/variable
    # "hello" = value

if mystring == "hello":
    # if = ???; 
    # mystring = variable?; 
    # == = ???; 
    # "hello" = ???
# checking if "mystring" is (equal to/containing) the string "hello"
    
    print("String: %s" % mystring)
        # print = function, whats in the () are the parameters; 
        # %s = certain format specifier; 
        # % = ???; 
        # mystring = variable
    # prints ... ???
# if the statement is TRUE, which is "mystring" is the string "hello", it will trigger the function to print the parameter"

else:
    # else = ???
# if the statement is FALSE, which is "mystring" is not "hello", it will do the function below
    print("String is not stringing")
# Out:
# String: hello
